# %%
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt

# %%
# Loading the Data
nypd = pd.read_csv('~/NYPD-CIV-COMPLAINTS/CCRB-Complaint_Data_202007261025/allegations_20200726939.csv')
nypd
# Out:
#        unique_mos_id first_name last_name command_now  complaint_id  \
# 0              10004   Jonathan      Ruiz     078 PCT         42835
# 1              10007       John     Sears     078 PCT         24601
# 2              10007       John     Sears     078 PCT         24601
# 3              10007       John     Sears     078 PCT         26146
# 4              10009      Noemi    Sierra     078 PCT         40253
# ...              ...        ...       ...         ...           ...
# 33353           9992     Tomasz  Pulawski     078 PCT         35671
# 33354           9992     Tomasz  Pulawski     078 PCT         35671
# 33355           9992     Tomasz  Pulawski     078 PCT         35671
# 33356           9992     Tomasz  Pulawski     078 PCT         35671
# 33357           9992     Tomasz  Pulawski     078 PCT         35671
#
#        month_received  year_received  month_closed  year_closed  \
# 0                   7           2019             5         2020
# 1                  11           2011             8         2012
# 2                  11           2011             8         2012
# 3                   7           2012             9         2013
# 4                   8           2018             2         2019
# ...               ...            ...           ...          ...
# 33353               8           2016             2         2017
# 33354               8           2016             2         2017
# 33355               8           2016             2         2017
# 33356               8           2016             2         2017
# 33357               8           2016             2         2017
#
#       command_at_incident  ... mos_age_incident complainant_ethnicity  \
# 0                 078 PCT  ...               32                 Black
# 1                    PBBS  ...               24                 Black
# 2                    PBBS  ...               24                 Black
# 3                    PBBS  ...               25                 Black
# 4                 078 PCT  ...               39                   NaN
# ...                   ...  ...              ...                   ...
# 33353             066 PCT  ...               36                 Asian
# 33354             066 PCT  ...               36                 Asian
# 33355             066 PCT  ...               36                 Asian
# 33356             066 PCT  ...               36                 Asian
# 33357             066 PCT  ...               36                 Asian
#
#       complainant_gender complainant_age_incident           fado_type  \
# 0                 Female                     38.0  Abuse of Authority
# 1                   Male                     26.0         Discourtesy
# 2                   Male                     26.0  Offensive Language
# 3                   Male                     45.0  Abuse of Authority
# 4                    NaN                     16.0               Force
# ...                  ...                      ...                 ...
# 33353               Male                     21.0         Discourtesy
# 33354               Male                     21.0  Abuse of Authority
# 33355               Male                     21.0  Abuse of Authority
# 33356               Male                     21.0  Abuse of Authority
# 33357               Male                     21.0  Abuse of Authority
#
#                          allegation  precinct  \
# 0      Failure to provide RTKA card      78.0
# 1                            Action      67.0
# 2                              Race      67.0
# 3                          Question      67.0
# 4                    Physical force      67.0
# ...                             ...       ...
# 33353                          Word      66.0
# 33354   Interference with recording      66.0
# 33355            Search (of person)      66.0
# 33356                Vehicle search      66.0
# 33357                         Frisk      66.0
#
#                                      contact_reason  \
# 0                           Report-domestic dispute
# 1                                  Moving violation
# 2                                  Moving violation
# 3      PD suspected C/V of violation/crime - street
# 4                                    Report-dispute
# ...                                             ...
# 33353                              Moving violation
# 33354                              Moving violation
# 33355                              Moving violation
# 33356                              Moving violation
# 33357                              Moving violation
#
#                     outcome_description  \
# 0      No arrest made or summons issued
# 1       Moving violation summons issued
# 2       Moving violation summons issued
# 3      No arrest made or summons issued
# 4        Arrest - other violation/crime
# ...                                 ...
# 33353   Moving violation summons issued
# 33354   Moving violation summons issued
# 33355   Moving violation summons issued
# 33356   Moving violation summons issued
# 33357   Moving violation summons issued
#
#                               board_disposition
# 0      Substantiated (Command Lvl Instructions)
# 1                       Substantiated (Charges)
# 2                       Substantiated (Charges)
# 3                       Substantiated (Charges)
# 4          Substantiated (Command Discipline A)
# ...                                         ...
# 33353                           Unsubstantiated
# 33354                           Unsubstantiated
# 33355       Substantiated (Formalized Training)
# 33356       Substantiated (Formalized Training)
# 33357       Substantiated (Formalized Training)
#
# [33358 rows x 26 columns]

# %%
# Saving to copy for safety
df = nypd.copy()

# %%
# Examining the DataFrame
df.head(10)
# Out:
#    unique_mos_id first_name last_name command_now  complaint_id  \
# 0          10004   Jonathan      Ruiz     078 PCT         42835
# 1          10007       John     Sears     078 PCT         24601
# 2          10007       John     Sears     078 PCT         24601
# 3          10007       John     Sears     078 PCT         26146
# 4          10009      Noemi    Sierra     078 PCT         40253
# 5          10012      Paula     Smith     078 PCT         37256
# 6          10014    Malachy  Sullivan     078 PCT         33969
# 7          10017      Fazle     Tanim     078 PCT         40070
# 8          10017      Fazle     Tanim     078 PCT         41927
# 9          10017      Fazle     Tanim     078 PCT         41927
#
#    month_received  year_received  month_closed  year_closed  \
# 0               7           2019             5         2020
# 1              11           2011             8         2012
# 2              11           2011             8         2012
# 3               7           2012             9         2013
# 4               8           2018             2         2019
# 5               5           2017            10         2017
# 6              11           2015             2         2016
# 7               8           2018            11         2018
# 8               3           2019             8         2019
# 9               3           2019             8         2019
#
#   command_at_incident  ... mos_age_incident complainant_ethnicity  \
# 0             078 PCT  ...               32                 Black
# 1                PBBS  ...               24                 Black
# 2                PBBS  ...               24                 Black
# 3                PBBS  ...               25                 Black
# 4             078 PCT  ...               39                   NaN
# 5             078 PCT  ...               50                 White
# 6             078 PCT  ...               43                 White
# 7             078 PCT  ...               34                 Asian
# 8             078 PCT  ...               35                 Asian
# 9             078 PCT  ...               35                 Asian
#
#   complainant_gender complainant_age_incident           fado_type  \
# 0             Female                     38.0  Abuse of Authority
# 1               Male                     26.0         Discourtesy
# 2               Male                     26.0  Offensive Language
# 3               Male                     45.0  Abuse of Authority
# 4                NaN                     16.0               Force
# 5               Male                     31.0  Abuse of Authority
# 6               Male                     34.0  Offensive Language
# 7               Male                     60.0         Discourtesy
# 8               Male                     39.0  Abuse of Authority
# 9               Male                     39.0  Abuse of Authority
#
#                               allegation  precinct  \
# 0           Failure to provide RTKA card      78.0
# 1                                 Action      67.0
# 2                                   Race      67.0
# 3                               Question      67.0
# 4                         Physical force      67.0
# 5  Refusal to process civilian complaint      78.0
# 6                     Sexual orientation      78.0
# 7                                   Word      78.0
# 8       Refusal to provide shield number      78.0
# 9                    Retaliatory summons      78.0
#
#                                  contact_reason  \
# 0                       Report-domestic dispute
# 1                              Moving violation
# 2                              Moving violation
# 3  PD suspected C/V of violation/crime - street
# 4                                Report-dispute
# 5                            C/V telephoned PCT
# 6  PD suspected C/V of violation/crime - street
# 7                              Moving violation
# 8                              Moving violation
# 9                              Moving violation
#
#                 outcome_description                         board_disposition
# 0  No arrest made or summons issued  Substantiated (Command Lvl Instructions)
# 1   Moving violation summons issued                   Substantiated (Charges)
# 2   Moving violation summons issued                   Substantiated (Charges)
# 3  No arrest made or summons issued                   Substantiated (Charges)
# 4    Arrest - other violation/crime      Substantiated (Command Discipline A)
# 5  No arrest made or summons issued  Substantiated (Command Lvl Instructions)
# 6   Summons - other violation/crime       Substantiated (Formalized Training)
# 7   Moving violation summons issued                           Unsubstantiated
# 8   Moving violation summons issued                           Unsubstantiated
# 9   Moving violation summons issued      Substantiated (Command Discipline A)
#
# [10 rows x 26 columns]

# %%
df.tail()
# Out:
#        unique_mos_id first_name last_name command_now  complaint_id  \
# 33353           9992     Tomasz  Pulawski     078 PCT         35671
# 33354           9992     Tomasz  Pulawski     078 PCT         35671
# 33355           9992     Tomasz  Pulawski     078 PCT         35671
# 33356           9992     Tomasz  Pulawski     078 PCT         35671
# 33357           9992     Tomasz  Pulawski     078 PCT         35671
#
#        month_received  year_received  month_closed  year_closed  \
# 33353               8           2016             2         2017
# 33354               8           2016             2         2017
# 33355               8           2016             2         2017
# 33356               8           2016             2         2017
# 33357               8           2016             2         2017
#
#       command_at_incident  ... mos_age_incident complainant_ethnicity  \
# 33353             066 PCT  ...               36                 Asian
# 33354             066 PCT  ...               36                 Asian
# 33355             066 PCT  ...               36                 Asian
# 33356             066 PCT  ...               36                 Asian
# 33357             066 PCT  ...               36                 Asian
#
#       complainant_gender complainant_age_incident           fado_type  \
# 33353               Male                     21.0         Discourtesy
# 33354               Male                     21.0  Abuse of Authority
# 33355               Male                     21.0  Abuse of Authority
# 33356               Male                     21.0  Abuse of Authority
# 33357               Male                     21.0  Abuse of Authority
#
#                         allegation  precinct    contact_reason  \
# 33353                         Word      66.0  Moving violation
# 33354  Interference with recording      66.0  Moving violation
# 33355           Search (of person)      66.0  Moving violation
# 33356               Vehicle search      66.0  Moving violation
# 33357                        Frisk      66.0  Moving violation
#
#                    outcome_description                    board_disposition
# 33353  Moving violation summons issued                      Unsubstantiated
# 33354  Moving violation summons issued                      Unsubstantiated
# 33355  Moving violation summons issued  Substantiated (Formalized Training)
# 33356  Moving violation summons issued  Substantiated (Formalized Training)
# 33357  Moving violation summons issued  Substantiated (Formalized Training)
#
# [5 rows x 26 columns]

# %%
df.shape
# Out:
# (33358, 26)

# %%
df.columns
# Out:
# Index(['unique_mos_id', 'first_name', 'last_name', 'command_now',
#        'complaint_id', 'month_received', 'year_received', 'month_closed',
#        'year_closed', 'command_at_incident', 'rank_abbrev_incident',
#        'rank_abbrev_now', 'rank_now', 'rank_incident', 'mos_ethnicity',
#        'mos_gender', 'mos_age_incident', 'complainant_ethnicity',
#        'complainant_gender', 'complainant_age_incident', 'fado_type',
#        'allegation', 'precinct', 'contact_reason', 'outcome_description',
#        'board_disposition'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=33358, step=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33358 entries, 0 to 33357
# Data columns (total 26 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   unique_mos_id             33358 non-null  int64
#  1   first_name                33358 non-null  object
#  2   last_name                 33358 non-null  object
#  3   command_now               33358 non-null  object
#  4   complaint_id              33358 non-null  int64
#  5   month_received            33358 non-null  int64
#  6   year_received             33358 non-null  int64
#  7   month_closed              33358 non-null  int64
#  8   year_closed               33358 non-null  int64
#  9   command_at_incident       31814 non-null  object
#  10  rank_abbrev_incident      33358 non-null  object
#  11  rank_abbrev_now           33358 non-null  object
#  12  rank_now                  33358 non-null  object
#  13  rank_incident             33358 non-null  object
#  14  mos_ethnicity             33358 non-null  object
#  15  mos_gender                33358 non-null  object
#  16  mos_age_incident          33358 non-null  int64
#  17  complainant_ethnicity     28894 non-null  object
#  18  complainant_gender        29163 non-null  object
#  19  complainant_age_incident  28546 non-null  float64
#  20  fado_type                 33358 non-null  object
#  21  allegation                33357 non-null  object
#  22  precinct                  33334 non-null  float64
#  23  contact_reason            33159 non-null  object
#  24  outcome_description       33302 non-null  object
#  25  board_disposition         33358 non-null  object
# dtypes: float64(2), int64(7), object(17)
# memory usage: 6.6+ MB

# %%
df.describe()
# Out:
#        unique_mos_id  complaint_id  month_received  year_received  \
# count   33358.000000  33358.000000    33358.000000   33358.000000
# mean    18169.912495  23905.058217        6.323551    2010.726782
# std      9566.316896  11954.434138        3.362951       6.034725
# min         2.000000    517.000000        1.000000    1985.000000
# 25%      9671.000000  13684.750000        3.000000    2007.000000
# 50%     19215.000000  25132.000000        6.000000    2012.000000
# 75%     25412.000000  34252.000000        9.000000    2016.000000
# max     36374.000000  43703.000000       12.000000    2020.000000
#
#        month_closed   year_closed  mos_age_incident  complainant_age_incident  \
# count  33358.000000  33358.000000      33358.000000              28546.000000
# mean       6.470772   2011.525661         32.346873                 32.484201
# std        3.343372      6.085907          6.040944                 28.408963
# min        1.000000   1985.000000         20.000000              -4301.000000
# 25%        4.000000   2008.000000         28.000000                 23.000000
# 50%        6.000000   2013.000000         31.000000                 30.000000
# 75%        9.000000   2016.000000         36.000000                 41.000000
# max       12.000000   2020.000000         60.000000                101.000000
#
#            precinct
# count  33334.000000
# mean      64.365213
# std       31.451592
# min        0.000000
# 25%       43.000000
# 50%       67.000000
# 75%       81.000000
# max     1000.000000

# %%
len(df)
# Out:
# 33358

# %%
#Exploring data from different angles

comp_types = df.groupby(['fado_type', 'allegation'])['complaint_id'].count().reset_index()
# comp_types
comp_types_s = df.groupby(['fado_type']).complaint_id.count().reset_index()
comp_types_s
# print(type(comp_types))
# Out:
#             fado_type  complaint_id
# 0  Abuse of Authority         20292
# 1         Discourtesy          4677
# 2               Force          7636
# 3  Offensive Language           753

# %%
# Quick barplot reflecting groupby code
# sns.set(style="whitegrid", color_codes=True)
sns.set_style('ticks')
ax = sns.barplot(x = 'fado_type', y = 'complaint_id', data = comp_types_s, palette = ["red", "green", "blue", "yellow"], ci = False)
# "Error bars" signify confidence interval can be removed with ci = False

# %%
# Switching axes to check for readability 
# sns.set(style="whitegrid", color_codes=True)
sns.set(rc={'figure.figsize': (16,3)})
ax = sns.barplot(x = 'complaint_id', y = 'fado_type', data = comp_types_s, palette = ["red", "green", "blue", "yellow"], orient = 'h', ci = False)

# %%
# Abuse of authority as a broader category has the most cumulative complaints, but let's take a closer look at complaints over time 
sns.set_style('ticks')
ax = sns.lineplot(x = 'year_received', y = 'complaint_id', data = df, style = 'fado_type', hue = 'fado_type', 
                  palette = ["red", "green", "blue", "yellow"], ci = False, markers = True)
# TODO: Redo graph using more specific parameters (individual lines)

# %%
# Teammate question/observation
# rh = df.loc[(df['first_name'] == 'Richard') & (df['last_name'] == 'Haste')]
# rh

# %%
# Complaints by gender
gen_com = df.groupby(['complainant_gender'])['complaint_id'].count().reset_index()
gen_com
# Out:
#       complainant_gender  complaint_id
# 0                 Female          5021
# 1  Gender non-conforming             2
# 2                   Male         24058
# 3          Not described            57
# 4         Transman (FTM)             5
# 5       Transwoman (MTF)            20

# %%
# Complaints by race
rc_com = df.groupby(['complainant_ethnicity'])['complaint_id'].count().reset_index()
rc_com
# Out:
#   complainant_ethnicity  complaint_id
# 0       American Indian            64
# 1                 Asian           532
# 2                 Black         17114
# 3              Hispanic          6424
# 4            Other Race           677
# 5               Refused           259
# 6               Unknown          1041
# 7                 White          2783

# %%
# Barplot of complaints by race
sns.set(rc={'figure.figsize': (16,3)})
sns.set_style('ticks')
ax = sns.barplot(x = 'complainant_ethnicity', y = 'complaint_id', data = rc_com, palette = ["orange"], ci = False)

plt.savefig('complainant_ethnicity.png', dpi=100)

# %%
# Count of complaints against cops by cops ethnicity
cp_rc = df.groupby(['mos_ethnicity'])['complaint_id'].count().reset_index()
cp_rc
# Out:
#      mos_ethnicity  complaint_id
# 0  American Indian            32
# 1            Asian          1178
# 2            Black          4924
# 3         Hispanic          9150
# 4            White         18074

# %%
# Barplot of complaints against cops by cop ethnicity
sns.set(rc={'figure.figsize': (16,3)})
sns.set_style('ticks')
ax = sns.barplot(x = 'mos_ethnicity', y = 'complaint_id', data = cp_rc, palette = ["blue"], ci = False)

plt.savefig('officer_ethnicity.png', dpi=100)

# %%
# Complaints by year
cp_by_yr = df.groupby(['year_received'])['complaint_id'].count().reset_index()
# cp_by_yr

ax = sns.lineplot(x = 'year_received', y = 'complaint_id', data = cp_by_yr)

# %%
# Percentage of complaint type by precinct and complainant race
pct_cp = df.groupby(['command_at_incident', 'fado_type', 'complainant_ethnicity'])['complaint_id'].count().reset_index()
pct_cp

pctcp_sorted = pct_cp.sort_values(['complaint_id'], ascending=[False])
pctcp_sorted
# Out:
#      command_at_incident           fado_type complainant_ethnicity  \
# 869              075 PCT  Abuse of Authority                 Black
# 943              079 PCT  Abuse of Authority                 Black
# 840              073 PCT  Abuse of Authority                 Black
# 908              077 PCT  Abuse of Authority                 Black
# 702              067 PCT  Abuse of Authority                 Black
# ...                  ...                 ...                   ...
# 1039             090 DET  Abuse of Authority                 White
# 2049             P A T U  Abuse of Authority                 White
# 1036             088 PCT               Force              Hispanic
# 1034             088 PCT         Discourtesy                 White
# 2741             WTC CMD               Force              Hispanic
#
#       complaint_id
# 869            570
# 943            381
# 840            348
# 908            334
# 702            311
# ...            ...
# 1039             1
# 2049             1
# 1036             1
# 1034             1
# 2741             1
#
# [2742 rows x 4 columns]

# %%
# Outcomes of complaints
out = df.groupby(['board_disposition'])['complaint_id'].count().reset_index()
out

# As percents
# out = df.groupby(['board_disposition'])['complaint_id'].value_counts(normalize=True) * 100
# out
# Out:
#                            board_disposition  complaint_id
# 0                                 Exonerated          9609
# 1                    Substantiated (Charges)          3796
# 2       Substantiated (Command Discipline A)           964
# 3       Substantiated (Command Discipline B)           789
# 4         Substantiated (Command Discipline)           851
# 5   Substantiated (Command Lvl Instructions)           454
# 6        Substantiated (Formalized Training)          1033
# 7               Substantiated (Instructions)           248
# 8           Substantiated (MOS Unidentified)             1
# 9         Substantiated (No Recommendations)           165
# 10                           Unsubstantiated         15448

# %%
# Creating police_id column, which combines unique_mos_id, first_name, and last_name for easier grouping

df['police_id'] = df[df.columns[0:3]].apply(
    lambda x: ' '.join(x.dropna().astype(str)),
    axis=1)
df
# Out:
#        unique_mos_id first_name last_name command_now  complaint_id  \
# 0              10004   Jonathan      Ruiz     078 PCT         42835
# 1              10007       John     Sears     078 PCT         24601
# 2              10007       John     Sears     078 PCT         24601
# 3              10007       John     Sears     078 PCT         26146
# 4              10009      Noemi    Sierra     078 PCT         40253
# ...              ...        ...       ...         ...           ...
# 33353           9992     Tomasz  Pulawski     078 PCT         35671
# 33354           9992     Tomasz  Pulawski     078 PCT         35671
# 33355           9992     Tomasz  Pulawski     078 PCT         35671
# 33356           9992     Tomasz  Pulawski     078 PCT         35671
# 33357           9992     Tomasz  Pulawski     078 PCT         35671
#
#        month_received  year_received  month_closed  year_closed  \
# 0                   7           2019             5         2020
# 1                  11           2011             8         2012
# 2                  11           2011             8         2012
# 3                   7           2012             9         2013
# 4                   8           2018             2         2019
# ...               ...            ...           ...          ...
# 33353               8           2016             2         2017
# 33354               8           2016             2         2017
# 33355               8           2016             2         2017
# 33356               8           2016             2         2017
# 33357               8           2016             2         2017
#
#       command_at_incident  ... complainant_ethnicity complainant_gender  \
# 0                 078 PCT  ...                 Black             Female
# 1                    PBBS  ...                 Black               Male
# 2                    PBBS  ...                 Black               Male
# 3                    PBBS  ...                 Black               Male
# 4                 078 PCT  ...                   NaN                NaN
# ...                   ...  ...                   ...                ...
# 33353             066 PCT  ...                 Asian               Male
# 33354             066 PCT  ...                 Asian               Male
# 33355             066 PCT  ...                 Asian               Male
# 33356             066 PCT  ...                 Asian               Male
# 33357             066 PCT  ...                 Asian               Male
#
#       complainant_age_incident           fado_type  \
# 0                         38.0  Abuse of Authority
# 1                         26.0         Discourtesy
# 2                         26.0  Offensive Language
# 3                         45.0  Abuse of Authority
# 4                         16.0               Force
# ...                        ...                 ...
# 33353                     21.0         Discourtesy
# 33354                     21.0  Abuse of Authority
# 33355                     21.0  Abuse of Authority
# 33356                     21.0  Abuse of Authority
# 33357                     21.0  Abuse of Authority
#
#                          allegation precinct  \
# 0      Failure to provide RTKA card     78.0
# 1                            Action     67.0
# 2                              Race     67.0
# 3                          Question     67.0
# 4                    Physical force     67.0
# ...                             ...      ...
# 33353                          Word     66.0
# 33354   Interference with recording     66.0
# 33355            Search (of person)     66.0
# 33356                Vehicle search     66.0
# 33357                         Frisk     66.0
#
#                                      contact_reason  \
# 0                           Report-domestic dispute
# 1                                  Moving violation
# 2                                  Moving violation
# 3      PD suspected C/V of violation/crime - street
# 4                                    Report-dispute
# ...                                             ...
# 33353                              Moving violation
# 33354                              Moving violation
# 33355                              Moving violation
# 33356                              Moving violation
# 33357                              Moving violation
#
#                     outcome_description  \
# 0      No arrest made or summons issued
# 1       Moving violation summons issued
# 2       Moving violation summons issued
# 3      No arrest made or summons issued
# 4        Arrest - other violation/crime
# ...                                 ...
# 33353   Moving violation summons issued
# 33354   Moving violation summons issued
# 33355   Moving violation summons issued
# 33356   Moving violation summons issued
# 33357   Moving violation summons issued
#
#                               board_disposition             police_id
# 0      Substantiated (Command Lvl Instructions)   10004 Jonathan Ruiz
# 1                       Substantiated (Charges)      10007 John Sears
# 2                       Substantiated (Charges)      10007 John Sears
# 3                       Substantiated (Charges)      10007 John Sears
# 4          Substantiated (Command Discipline A)    10009 Noemi Sierra
# ...                                         ...                   ...
# 33353                           Unsubstantiated  9992 Tomasz Pulawski
# 33354                           Unsubstantiated  9992 Tomasz Pulawski
# 33355       Substantiated (Formalized Training)  9992 Tomasz Pulawski
# 33356       Substantiated (Formalized Training)  9992 Tomasz Pulawski
# 33357       Substantiated (Formalized Training)  9992 Tomasz Pulawski
#
# [33358 rows x 27 columns]

# %%
# Grouping by police_id

unique_grouping = df.groupby(['police_id']).complaint_id.count().reset_index()
unique_grouping
# Out:
#                    police_id  complaint_id
# 0        10004 Jonathan Ruiz             1
# 1           10007 John Sears             3
# 2         10009 Noemi Sierra             1
# 3          10012 Paula Smith             1
# 4     10014 Malachy Sullivan             1
# ...                      ...           ...
# 3991     9974 Alex Merizalde             4
# 3992     9975 Inna Miroshnyk             2
# 3993      9979 Novaidul Neon             3
# 3994       9984 Hassan Paris             7
# 3995    9992 Tomasz Pulawski             6
#
# [3996 rows x 2 columns]

# %%
# Taking the average of the count of complaint_id to see what the average amount of complaints per officer is.

unique_grouping['complaint_id'].mean()
# Out:
# 8.347847847847849

# %%
# Selecting the cops with complaints greater than the average

prob_cops = unique_grouping.loc[unique_grouping['complaint_id'] > 8]
# print(type(prob_cops))
prob_cops
# Out:
#                     police_id  complaint_id
# 7       10026 Brian Alexander            26
# 8         10028 Elijah Austin            11
# 10       10039 Willie Johnson            41
# 12         10042 John Musante            20
# 14    10064 Anthony Bomparola            19
# ...                       ...           ...
# 3970      9674 Gabriel Cuevas            20
# 3971         9681 Eric Delman            29
# 3973     9707 Ashley Griffith            10
# 3978      9796 Steven Rupnick            15
# 3983        9856 Daniel Zollo            16
#
# [1411 rows x 2 columns]

# %%
# Saving prob_cops to csv to share with team

prob_cops.to_csv('problem_cops.csv')

# %%
# TODO: Create entirely new dataset reflecting only relevant data (police_id, count_of_complaint_id, command_now,
# command_at_incident, rank_now, rank_at_incident, fado_type, allegation, board_disposition)

new_df = df[['police_id', 'command_now', 'command_at_incident','rank_now', 'rank_incident', 
             'complaint_id','fado_type', 'allegation', 'board_disposition']]
new_df
# Out:
#                   police_id command_now command_at_incident        rank_now  \
# 0       10004 Jonathan Ruiz     078 PCT             078 PCT  Police Officer
# 1          10007 John Sears     078 PCT                PBBS  Police Officer
# 2          10007 John Sears     078 PCT                PBBS  Police Officer
# 3          10007 John Sears     078 PCT                PBBS  Police Officer
# 4        10009 Noemi Sierra     078 PCT             078 PCT  Police Officer
# ...                     ...         ...                 ...             ...
# 33353  9992 Tomasz Pulawski     078 PCT             066 PCT        Sergeant
# 33354  9992 Tomasz Pulawski     078 PCT             066 PCT        Sergeant
# 33355  9992 Tomasz Pulawski     078 PCT             066 PCT        Sergeant
# 33356  9992 Tomasz Pulawski     078 PCT             066 PCT        Sergeant
# 33357  9992 Tomasz Pulawski     078 PCT             066 PCT        Sergeant
#
#         rank_incident  complaint_id           fado_type  \
# 0      Police Officer         42835  Abuse of Authority
# 1      Police Officer         24601         Discourtesy
# 2      Police Officer         24601  Offensive Language
# 3      Police Officer         26146  Abuse of Authority
# 4      Police Officer         40253               Force
# ...               ...           ...                 ...
# 33353  Police Officer         35671         Discourtesy
# 33354  Police Officer         35671  Abuse of Authority
# 33355  Police Officer         35671  Abuse of Authority
# 33356  Police Officer         35671  Abuse of Authority
# 33357  Police Officer         35671  Abuse of Authority
#
#                          allegation                         board_disposition
# 0      Failure to provide RTKA card  Substantiated (Command Lvl Instructions)
# 1                            Action                   Substantiated (Charges)
# 2                              Race                   Substantiated (Charges)
# 3                          Question                   Substantiated (Charges)
# 4                    Physical force      Substantiated (Command Discipline A)
# ...                             ...                                       ...
# 33353                          Word                           Unsubstantiated
# 33354   Interference with recording                           Unsubstantiated
# 33355            Search (of person)       Substantiated (Formalized Training)
# 33356                Vehicle search       Substantiated (Formalized Training)
# 33357                         Frisk       Substantiated (Formalized Training)
#
# [33358 rows x 9 columns]

# %%
# df.groupby(['police_id'])['complaint_id'].filter(lambda x: x.count() > 8).index
whatever_var = list(df.groupby(['police_id'])['complaint_id'].filter(lambda x: x.count() > 8).index)
don_help = df.iloc[whatever_var]

# %%
# Test filter
don_help[don_help['last_name'] == 'Zollo']
# Out:
#        unique_mos_id first_name last_name command_now  complaint_id  \
# 33305           9856     Daniel     Zollo     077 PCT          8222
# 33306           9856     Daniel     Zollo     077 PCT         11266
# 33307           9856     Daniel     Zollo     077 PCT         17560
# 33308           9856     Daniel     Zollo     077 PCT         17560
# 33309           9856     Daniel     Zollo     077 PCT         17848
# 33310           9856     Daniel     Zollo     077 PCT         18754
# 33311           9856     Daniel     Zollo     077 PCT         19009
# 33312           9856     Daniel     Zollo     077 PCT         20709
# 33313           9856     Daniel     Zollo     077 PCT         20709
# 33314           9856     Daniel     Zollo     077 PCT         20709
# 33315           9856     Daniel     Zollo     077 PCT         20709
# 33316           9856     Daniel     Zollo     077 PCT         20786
# 33317           9856     Daniel     Zollo     077 PCT         20786
# 33318           9856     Daniel     Zollo     077 PCT         20786
# 33319           9856     Daniel     Zollo     077 PCT         20786
# 33320           9856     Daniel     Zollo     077 PCT         23623
#
#        month_received  year_received  month_closed  year_closed  \
# 33305               9           2004             4         2005
# 33306               5           2006             3         2007
# 33307               2           2009            12         2009
# 33308               2           2009            12         2009
# 33309               3           2009             2         2010
# 33310               8           2009             7         2010
# 33311               9           2009             8         2010
# 33312               6           2010             4         2011
# 33313               6           2010             4         2011
# 33314               6           2010             4         2011
# 33315               6           2010             4         2011
# 33316               6           2010             4         2011
# 33317               6           2010             4         2011
# 33318               6           2010             4         2011
# 33319               6           2010             4         2011
# 33320               6           2011             1         2013
#
#       command_at_incident  ... complainant_ethnicity complainant_gender  \
# 33305             TB BKTF  ...                 Black             Female
# 33306             077 PCT  ...                 Black               Male
# 33307             077 PCT  ...                 Black               Male
# 33308             077 PCT  ...                 Black               Male
# 33309             077 PCT  ...                 Black               Male
# 33310             077 PCT  ...                 Black               Male
# 33311             077 PCT  ...                   NaN                NaN
# 33312             077 PCT  ...                 Black               Male
# 33313             077 PCT  ...                 Black               Male
# 33314             077 PCT  ...                 Black               Male
# 33315             077 PCT  ...                 Black               Male
# 33316             077 PCT  ...                 Black             Female
# 33317             077 PCT  ...                 Black               Male
# 33318             077 PCT  ...                 Black               Male
# 33319             077 PCT  ...                 Black               Male
# 33320             077 PCT  ...                 Black               Male
#
#       complainant_age_incident           fado_type  \
# 33305                     15.0  Abuse of Authority
# 33306                     42.0  Abuse of Authority
# 33307                     25.0         Discourtesy
# 33308                     25.0               Force
# 33309                     49.0  Abuse of Authority
# 33310                     28.0  Abuse of Authority
# 33311                      NaN  Abuse of Authority
# 33312                     47.0  Abuse of Authority
# 33313                     47.0  Abuse of Authority
# 33314                     47.0  Abuse of Authority
# 33315                     47.0  Abuse of Authority
# 33316                     46.0  Abuse of Authority
# 33317                     39.0  Abuse of Authority
# 33318                     39.0         Discourtesy
# 33319                     39.0         Discourtesy
# 33320                     17.0               Force
#
#                                   allegation precinct  \
# 33305                    Seizure of property     94.0
# 33306                         Strip-searched     77.0
# 33307                                   Word     77.0
# 33308                         Physical force     77.0
# 33309                                   Stop     77.0
# 33310                    Retaliatory summons     77.0
# 33311       Premises entered and/or searched     77.0
# 33312                                   Stop     77.0
# 33313                         Vehicle search     77.0
# 33314                                  Frisk     77.0
# 33315                     Search (of person)     77.0
# 33316  Refusal to process civilian complaint     77.0
# 33317   Threat of force (verbal or physical)     77.0
# 33318                                   Word     77.0
# 33319                                   Word     77.0
# 33320                         Physical force     77.0
#
#                                      contact_reason  \
# 33305  PD suspected C/V of violation/crime - subway
# 33306    PD suspected C/V of violation/crime - auto
# 33307                             Parking violation
# 33308                             Parking violation
# 33309  PD suspected C/V of violation/crime - street
# 33310  PD suspected C/V of violation/crime - street
# 33311    PD suspected C/V of violation/crime - bldg
# 33312  PD suspected C/V of violation/crime - street
# 33313  PD suspected C/V of violation/crime - street
# 33314  PD suspected C/V of violation/crime - street
# 33315  PD suspected C/V of violation/crime - street
# 33316                                         Other
# 33317                                         Other
# 33318                                         Other
# 33319                                         Other
# 33320                                         Other
#
#                     outcome_description                   board_disposition  \
# 33305  No arrest made or summons issued                          Exonerated
# 33306    Arrest - other violation/crime                     Unsubstantiated
# 33307    Arrest - other violation/crime                     Unsubstantiated
# 33308    Arrest - other violation/crime                          Exonerated
# 33309       Arrest - disorderly conduct                     Unsubstantiated
# 33310      Summons - disorderly conduct             Substantiated (Charges)
# 33311   Summons - other violation/crime  Substantiated (Command Discipline)
# 33312  No arrest made or summons issued                     Unsubstantiated
# 33313  No arrest made or summons issued                     Unsubstantiated
# 33314  No arrest made or summons issued                          Exonerated
# 33315  No arrest made or summons issued                     Unsubstantiated
# 33316    Arrest - other violation/crime                     Unsubstantiated
# 33317    Arrest - other violation/crime                     Unsubstantiated
# 33318    Arrest - other violation/crime                     Unsubstantiated
# 33319    Arrest - other violation/crime             Substantiated (Charges)
# 33320    Arrest - other violation/crime                     Unsubstantiated
#
#                police_id
# 33305  9856 Daniel Zollo
# 33306  9856 Daniel Zollo
# 33307  9856 Daniel Zollo
# 33308  9856 Daniel Zollo
# 33309  9856 Daniel Zollo
# 33310  9856 Daniel Zollo
# 33311  9856 Daniel Zollo
# 33312  9856 Daniel Zollo
# 33313  9856 Daniel Zollo
# 33314  9856 Daniel Zollo
# 33315  9856 Daniel Zollo
# 33316  9856 Daniel Zollo
# 33317  9856 Daniel Zollo
# 33318  9856 Daniel Zollo
# 33319  9856 Daniel Zollo
# 33320  9856 Daniel Zollo
#
# [16 rows x 27 columns]

# %%
# Saving to csv file
don_help.to_csv('NYPD_data_new.csv')

# %%
# Donut chart of outcomes: substantiated, unsubstantiated, exonerated

mm_donut = df.copy()
# mm_donut

# Replacing any Substantiated subcat w/ 'Substantiated' for cleaner graph

mm_donut['board_disposition'] = mm_donut['board_disposition'].replace(['Substantiated (Charges)'],'Substantiated')
mm_donut['board_disposition'] = mm_donut['board_disposition'].replace(['Substantiated (Command Discipline A)'], 'Substantiated')
mm_donut['board_disposition'] = mm_donut['board_disposition'].replace(['Substantiated (Command Discipline B)'], 'Substantiated')
mm_donut['board_disposition'] = mm_donut['board_disposition'].replace(['Substantiated (Command Discipline)'], 'Substantiated')
mm_donut['board_disposition'] = mm_donut['board_disposition'].replace(['Substantiated (Command Lvl Instructions)'], 'Substantiated')
mm_donut['board_disposition'] = mm_donut['board_disposition'].replace(['Substantiated (Formalized Training)'], 'Substantiated')
mm_donut['board_disposition'] = mm_donut['board_disposition'].replace(['Substantiated (Instructions)'], 'Substantiated')
mm_donut['board_disposition'] = mm_donut['board_disposition'].replace(['Substantiated (MOS Unidentified)'], 'Substantiated')
mm_donut['board_disposition'] = mm_donut['board_disposition'].replace(['Substantiated (No Recommendations)'], 'Substantiated')
mm_donut
# Out:
#        unique_mos_id first_name last_name command_now  complaint_id  \
# 0              10004   Jonathan      Ruiz     078 PCT         42835
# 1              10007       John     Sears     078 PCT         24601
# 2              10007       John     Sears     078 PCT         24601
# 3              10007       John     Sears     078 PCT         26146
# 4              10009      Noemi    Sierra     078 PCT         40253
# ...              ...        ...       ...         ...           ...
# 33353           9992     Tomasz  Pulawski     078 PCT         35671
# 33354           9992     Tomasz  Pulawski     078 PCT         35671
# 33355           9992     Tomasz  Pulawski     078 PCT         35671
# 33356           9992     Tomasz  Pulawski     078 PCT         35671
# 33357           9992     Tomasz  Pulawski     078 PCT         35671
#
#        month_received  year_received  month_closed  year_closed  \
# 0                   7           2019             5         2020
# 1                  11           2011             8         2012
# 2                  11           2011             8         2012
# 3                   7           2012             9         2013
# 4                   8           2018             2         2019
# ...               ...            ...           ...          ...
# 33353               8           2016             2         2017
# 33354               8           2016             2         2017
# 33355               8           2016             2         2017
# 33356               8           2016             2         2017
# 33357               8           2016             2         2017
#
#       command_at_incident  ... complainant_ethnicity complainant_gender  \
# 0                 078 PCT  ...                 Black             Female
# 1                    PBBS  ...                 Black               Male
# 2                    PBBS  ...                 Black               Male
# 3                    PBBS  ...                 Black               Male
# 4                 078 PCT  ...                   NaN                NaN
# ...                   ...  ...                   ...                ...
# 33353             066 PCT  ...                 Asian               Male
# 33354             066 PCT  ...                 Asian               Male
# 33355             066 PCT  ...                 Asian               Male
# 33356             066 PCT  ...                 Asian               Male
# 33357             066 PCT  ...                 Asian               Male
#
#       complainant_age_incident           fado_type  \
# 0                         38.0  Abuse of Authority
# 1                         26.0         Discourtesy
# 2                         26.0  Offensive Language
# 3                         45.0  Abuse of Authority
# 4                         16.0               Force
# ...                        ...                 ...
# 33353                     21.0         Discourtesy
# 33354                     21.0  Abuse of Authority
# 33355                     21.0  Abuse of Authority
# 33356                     21.0  Abuse of Authority
# 33357                     21.0  Abuse of Authority
#
#                          allegation precinct  \
# 0      Failure to provide RTKA card     78.0
# 1                            Action     67.0
# 2                              Race     67.0
# 3                          Question     67.0
# 4                    Physical force     67.0
# ...                             ...      ...
# 33353                          Word     66.0
# 33354   Interference with recording     66.0
# 33355            Search (of person)     66.0
# 33356                Vehicle search     66.0
# 33357                         Frisk     66.0
#
#                                      contact_reason  \
# 0                           Report-domestic dispute
# 1                                  Moving violation
# 2                                  Moving violation
# 3      PD suspected C/V of violation/crime - street
# 4                                    Report-dispute
# ...                                             ...
# 33353                              Moving violation
# 33354                              Moving violation
# 33355                              Moving violation
# 33356                              Moving violation
# 33357                              Moving violation
#
#                     outcome_description board_disposition  \
# 0      No arrest made or summons issued     Substantiated
# 1       Moving violation summons issued     Substantiated
# 2       Moving violation summons issued     Substantiated
# 3      No arrest made or summons issued     Substantiated
# 4        Arrest - other violation/crime     Substantiated
# ...                                 ...               ...
# 33353   Moving violation summons issued   Unsubstantiated
# 33354   Moving violation summons issued   Unsubstantiated
# 33355   Moving violation summons issued     Substantiated
# 33356   Moving violation summons issued     Substantiated
# 33357   Moving violation summons issued     Substantiated
#
#                   police_id
# 0       10004 Jonathan Ruiz
# 1          10007 John Sears
# 2          10007 John Sears
# 3          10007 John Sears
# 4        10009 Noemi Sierra
# ...                     ...
# 33353  9992 Tomasz Pulawski
# 33354  9992 Tomasz Pulawski
# 33355  9992 Tomasz Pulawski
# 33356  9992 Tomasz Pulawski
# 33357  9992 Tomasz Pulawski
#
# [33358 rows x 27 columns]

# %%
# Group by board_disposition and count complaint_id

mm_donut.groupby(['board_disposition'])['complaint_id'].count().reset_index()
# Out:
#   board_disposition  complaint_id
# 0        Exonerated          9609
# 1     Substantiated          8301
# 2   Unsubstantiated         15448

# %%
# Donut chart (continued)

# create data
names=[r'Exonerated (29 %)', r'Substantiated (25 %)', 
r'Unsubstantiated (46 %)']
size=[9609,8301,15448]
 
# Create a circle for the center of the plot
my_circle=plt.Circle( (0,0), 0.7, color='black')

# Give color names
# plt.pie(size, labels=names, colors=['red','green','blue'])
# p=plt.gcf()
# p.gca().add_artist(my_circle)
# plt.show()

# Label distance: gives the space between labels and the center of the pie
# plt.pie(size, labels=names, labeldistance=0.45)
# p=plt.gcf()
# p.gca().add_artist(my_circle)
# plt.show()
 
# Label color
# plt.rcParams['text.color'] = 'red'
# plt.pie(size, labels=names)
# p=plt.gcf()
# p.gca().add_artist(my_circle)
# plt.show()

# Custom wedges
# plt.pie(size, labels=names, wedgeprops = { 'linewidth' : 7, 'edgecolor' : 'white' })
# p=plt.gcf()
# p.gca().add_artist(my_circle)
# plt.show()

plt.rcParams['text.color'] = 'red'
fig = plt.figure()
fig.patch.set_facecolor('black')

plt.pie(size, labels=names, colors=['red','green','blue'], labeldistance=1.15, 
        wedgeprops = { 'linewidth' : 7, 'edgecolor' : 'black' })
p=plt.gcf()
p.gca().add_artist(my_circle)
plt.title('CCRB Findings')

plt.savefig('donut.png', dpi=100)

plt.show()

# %%
# Donut chart (white)

# create data
names=[r'Exonerated (29 %)', r'Substantiated (25 %)', 
r'Unsubstantiated (46 %)']
size=[9609,8301,15448]
 
# Create a circle for the center of the plot
my_circle=plt.Circle( (0,0), 0.7, color='white')


plt.rcParams['text.color'] = 'black'
fig = plt.figure()
fig.patch.set_facecolor('white')

plt.pie(size, labels=names, colors=['red','green','blue'], labeldistance=1.15, 
        wedgeprops = { 'linewidth' : 7, 'edgecolor' : 'white' })
p=plt.gcf()
p.gca().add_artist(my_circle)
plt.title('CCRB Findings')

plt.savefig('donut_white.png', dpi=100)

plt.show()

# %%
# Complaints by precinct

precincts = df.groupby(['command_at_incident'])['complaint_id'].count().sort_values(ascending=False).reset_index()
precincts
# Out:
#     command_at_incident  complaint_id
# 0               075 PCT          1364
# 1               046 PCT           825
# 2               044 PCT           763
# 3               NARCBBN           746
# 4               079 PCT           737
# ..                  ...           ...
# 356             032 DET             1
# 357             PBQS SC             1
# 358              DA QNS             1
# 359             028 DET             1
# 360             GANG DV             1
#
# [361 rows x 2 columns]

# %%
# Saving precincts to csv for further manipulation

precincts.to_csv('precincts_complaints.csv')

# %%
# Reference code for saving images to local machine
# plt.savefig("foo.png", transparent=True)
